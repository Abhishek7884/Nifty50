# %% [markdown]
# # #Nifty50

# %%
import os
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.chdir("C:/Users/abhis/Downloads")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\abhis\\Downloads'

# %%
import pandas as pd
data2=pd.read_csv("NIFTY50.csv")
data2
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n  PCLOSE \n     LTP \n  \
# 0     NIFTY 50  17,923.35  17,925.95  17,786.00  17,798.75  17,833.35
# 1        TECHM   1,102.65   1,132.35   1,086.25   1,089.60   1,127.00
# 2   ADANIPORTS      888.8        925        887     885.05        909
# 3         INFY   1,488.00   1,520.00   1,480.00   1,475.90   1,512.00
# 4   INDUSINDBK   1,119.00   1,149.55   1,116.55   1,108.30   1,134.00
# 5      HCLTECH        939        953      934.3     931.05      950.1
# 6       MARUTI   8,834.65   8,989.00   8,730.00   8,790.65   8,953.00
# 7          TCS   3,195.00   3,233.50   3,168.50   3,169.65   3,220.00
# 8         ONGC      132.5      134.2     131.95     131.85      133.9
# 9     HINDALCO        426     430.65     423.25     420.55     426.45
# 10   EICHERMOT   3,460.00   3,483.00   3,427.05   3,425.75   3,473.00
# 11        SBIN     549.65        557        548     544.65     551.95
# ...

# %%
data2.describe()
data2.columns
# Out:
# Index(['SYMBOL \n', 'OPEN \n', 'HIGH \n', 'LOW \n', 'PCLOSE \n', 'LTP \n',
#        'CHNG \n', 'PercentageCHNG \n', 'VOLUME ', 'VALUE ', '52WH \n',
#        '52WL \n', '365Dper CHNG \n 08Sep2021', '30DperCHNG \n 08Aug2022'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# SYMBOL \n                     object
# OPEN \n                       object
# HIGH \n                       object
# LOW \n                        object
# PCLOSE \n                     object
# LTP \n                        object
# CHNG \n                       object
# PercentageCHNG \n             object
# VOLUME                         int64
# VALUE                         object
# 52WH \n                       object
# 52WL \n                       object
# 365Dper CHNG \n 08Sep2021    float64
# 30DperCHNG \n 08Aug2022      float64
# dtype: object

# %%
data2.corr()
# Out:
#                             VOLUME   365Dper CHNG \n 08Sep2021  \
# VOLUME                     1.000000                  -0.068568
# 365Dper CHNG \n 08Sep2021 -0.068568                   1.000000
# 30DperCHNG \n 08Aug2022   -0.024446                   0.301595
#
#                            30DperCHNG \n 08Aug2022
# VOLUME                                   -0.024446
# 365Dper CHNG \n 08Sep2021                 0.301595
# 30DperCHNG \n 08Aug2022                   1.000000

# %%
data2.cov()
# Out:
#                                 VOLUME   365Dper CHNG \n 08Sep2021  \
# VOLUME                     1.468559e+15              -7.144820e+07
# 365Dper CHNG \n 08Sep2021 -7.144820e+07               7.393432e+02
# 30DperCHNG \n 08Aug2022   -4.887255e+06               4.278142e+01
#
#                            30DperCHNG \n 08Aug2022
# VOLUME                               -4.887255e+06
# 365Dper CHNG \n 08Sep2021             4.278142e+01
# 30DperCHNG \n 08Aug2022               2.721553e+01

# %%
data2.isnull().sum()
# Out:
# SYMBOL \n                    0
# OPEN \n                      0
# HIGH \n                      0
# LOW \n                       0
# PCLOSE \n                    0
# LTP \n                       0
# CHNG \n                      0
# PercentageCHNG \n            0
# VOLUME                       0
# VALUE                        0
# 52WH \n                      0
# 52WL \n                      0
# 365Dper CHNG \n 08Sep2021    0
# 30DperCHNG \n 08Aug2022      0
# dtype: int64

# %%
df1=pd.DataFrame(data2)
cols=['SYMBOL \n', 'OPEN \n', 'HIGH \n', 'LOW \n', 'PCLOSE \n', 'LTP \n',
       'CHNG \n', 'PercentageCHNG \n', 'VOLUME ', 'VALUE ', '52WH \n',
       '52WL \n', '365Dper CHNG \n 08Sep2021', '30DperCHNG \n 08Aug2022']
df1[cols] = df1[cols].fillna(df1.mean().iloc[0])
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_9756\4148680124.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1[cols] = df1[cols].fillna(df1.mean().iloc[0])

# %%
df1.isnull().sum()
# Out:
# SYMBOL \n                    0
# OPEN \n                      0
# HIGH \n                      0
# LOW \n                       0
# PCLOSE \n                    0
# LTP \n                       0
# CHNG \n                      0
# PercentageCHNG \n            0
# VOLUME                       0
# VALUE                        0
# 52WH \n                      0
# 52WL \n                      0
# 365Dper CHNG \n 08Sep2021    0
# 30DperCHNG \n 08Aug2022      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['VALUE '].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['VALUE '].hist(bins=1000)
# Out:
# <AxesSubplot:>

# %%
df1.boxplot(column='365Dper CHNG \n 08Sep2021')
# Out:
# <AxesSubplot:>

# %%
df1.boxplot(column='30DperCHNG \n 08Aug2022')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.pairplot(df1)

# %%
sns.distplot(df1['365Dper CHNG \n 08Sep2021'])
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_9756\3737891040.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['365Dper CHNG \n 08Sep2021'])
# <AxesSubplot:xlabel='365Dper CHNG \n 08Sep2021', ylabel='Density'>

# %%
sns.distplot(df1['30DperCHNG \n 08Aug2022'])
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_9756\1106296492.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['30DperCHNG \n 08Aug2022'])
# <AxesSubplot:xlabel='30DperCHNG \n 08Aug2022', ylabel='Density'>

# %%
f1=df1.drop(['OPEN \n', 'HIGH \n', ],axis=1)
df1
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n  PCLOSE \n     LTP \n  \
# 0     NIFTY 50  17,923.35  17,925.95  17,786.00  17,798.75  17,833.35
# 1        TECHM   1,102.65   1,132.35   1,086.25   1,089.60   1,127.00
# 2   ADANIPORTS      888.8        925        887     885.05        909
# 3         INFY   1,488.00   1,520.00   1,480.00   1,475.90   1,512.00
# 4   INDUSINDBK   1,119.00   1,149.55   1,116.55   1,108.30   1,134.00
# 5      HCLTECH        939        953      934.3     931.05      950.1
# 6       MARUTI   8,834.65   8,989.00   8,730.00   8,790.65   8,953.00
# 7          TCS   3,195.00   3,233.50   3,168.50   3,169.65   3,220.00
# 8         ONGC      132.5      134.2     131.95     131.85      133.9
# 9     HINDALCO        426     430.65     423.25     420.55     426.45
# 10   EICHERMOT   3,460.00   3,483.00   3,427.05   3,425.75   3,473.00
# 11        SBIN     549.65        557        548     544.65     551.95
# ...

# %%
x=df1.iloc[:,1]

y=df1.iloc[:,-1]

# %%
x_var=df1['365Dper CHNG \n 08Sep2021']
y_var=df1[ '30DperCHNG \n 08Aug2022']
import statsmodels.api as sm
model=sm.OLS(y_var,x_var).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ...
# Dep. Variable:     30DperCHNG
#  08Aug2022   R-squared (uncentered):                   0.109
# Model:                                OLS   Adj. R-squared (uncentered):              0.091
# Method:                     Least Squares   F-statistic:                              6.102
# Date:                    Mon, 12 Sep 2022   Prob (F-statistic):                      0.0170
# Time:                            13:36:02   Log-Likelihood:                         -158.01
# No. Observations:                      51   AIC:                                      318.0
# Df Residuals:                          50   BIC:                                      320.0
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)

# %%
features = x_train.values.reshape(-1,1)

# %%
labels = y_train.values.reshape(-1,1)

# %%
x=features
y=labels

# %%
x=df1.iloc[:,0:6]
y=df1.iloc[:,-1]

# %%
x
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n  PCLOSE \n     LTP \n
# 0     NIFTY 50  17,923.35  17,925.95  17,786.00  17,798.75  17,833.35
# 1        TECHM   1,102.65   1,132.35   1,086.25   1,089.60   1,127.00
# 2   ADANIPORTS      888.8        925        887     885.05        909
# 3         INFY   1,488.00   1,520.00   1,480.00   1,475.90   1,512.00
# 4   INDUSINDBK   1,119.00   1,149.55   1,116.55   1,108.30   1,134.00
# 5      HCLTECH        939        953      934.3     931.05      950.1
# 6       MARUTI   8,834.65   8,989.00   8,730.00   8,790.65   8,953.00
# 7          TCS   3,195.00   3,233.50   3,168.50   3,169.65   3,220.00
# 8         ONGC      132.5      134.2     131.95     131.85      133.9
# 9     HINDALCO        426     430.65     423.25     420.55     426.45
# 10   EICHERMOT   3,460.00   3,483.00   3,427.05   3,425.75   3,473.00
# 11        SBIN     549.65        557        548     544.65     551.95
# ...

# %%
y
# Out:
# 0      1.70
# 1      6.77
# 2     14.71
# 3     -5.67
# 4      6.97
# 5     -0.37
# 6      0.75
# 7     -4.07
# 8      0.15
# 9     -3.20
# 10    10.10
# 11     7.51
# 12    -1.26
# 13    -3.02
# 14    -6.23
# 15    -8.76
# 16    -3.04
# 17     6.20
# 18    -2.05
# 19     6.19
# 20     8.07
# 21     2.51
# 22     6.20
# 23     2.20
# 24    -3.21
# 25    -4.62
# 26     1.92
# 27     0.89
# 28    16.11
# 29     5.36
# 30     6.97
# 31     7.06
# 32     3.11
# 33     3.26
# 34     0.28
# 35    -3.23
# 36    -0.27
# 37     2.27
# 38    -0.51
# 39    -3.63
# 40     0.05
# 41     1.38
# 42     9.99
# 43     6.98
# 44     0.44
# 45     5.10
# 46     8.53
# 47     6.48
# 48     2.62
# 49     1.90
# 50     2.85
# Name: 30DperCHNG \n 08Aug2022, dtype: float64

# %%
#Splitting the dataset into Training set and Test set
from sklearn import model_selection, neighbors
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1,random_state=5)
features = x_train.iloc[:,:].values
features
# Out:
# array([['MARUTI', '8,834.65', '8,989.00', '8,730.00', '8,790.65',
#         '8,953.00'],
#        ['BPCL', '341.5', '341.55', '336.05', '339.85', '338.45'],
#        ['ADANIPORTS', '888.8', '925', '887', '885.05', '909'],
#        ['INFY', '1,488.00', '1,520.00', '1,480.00', '1,475.90',
#         '1,512.00'],
#        ['SHREECEM', '24,587.00', '25,550.00', '24,232.50', '24,458.45',
#         '24,398.45'],
#        ['HEROMOTOCO', '2,871.60', '2,878.25', '2,832.70', '2,857.30',
#         '2,840.00'],
#        ['INDUSINDBK', '1,119.00', '1,149.55', '1,116.55', '1,108.30',
#         '1,134.00'],
#        ['AXISBANK', '787.95', '787.95', '780', '779.75', '784'],
#        ['NIFTY 50', '17,923.35', '17,925.95', '17,786.00', '17,798.75',
#         '17,833.35'],
#        ['TATASTEEL', '107', '107.35', '105.5', '105.85', '105.85'],
#        ['HCLTECH', '939', '953', '934.3', '931.05', '950.1'],
#        ['SBILIFE', '1,322.05', '1,326.95', '1,291.30', '1,317.70',
#         '1,297.80'],
# ...

# %%
sns.heatmap(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 sns.heatmap(x)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:543, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     540     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     541 """
#     542 # Initialize the plotter object
# --> 543 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     544                       annot_kws, cbar, cbar_kws, xticklabels,
#     545                       yticklabels, mask)
#     547 # Add the pcolormesh kwargs here
# ...

# %%
sns.heatmap(data2.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data2.cov())
# Out:
# <AxesSubplot:>
